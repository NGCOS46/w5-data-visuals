# %%
import pandas as pd

# %%
csv=r"C:\Users\VANT\ironhack\ejercicios\w5-data-visuals\data\raw_fighter_details.csv"

fighter_stats=pd.read_csv(csv)

# %%
fighter_stats
# Out:
#              fighter_name  Height    Weight Reach    Stance           DOB  \
# 0               Tom Aaron     NaN  155 lbs.   NaN       NaN  Jul 13, 1978
# 1              Papy Abedi  5' 11"  185 lbs.   NaN  Southpaw  Jun 30, 1978
# 2     Shamil Abdurakhimov   6' 3"  235 lbs.   76"  Orthodox  Sep 02, 1981
# 3            Danny Abbadi  5' 11"  155 lbs.   NaN  Orthodox  Jul 03, 1983
# 4            Hiroyuki Abe   5' 6"  145 lbs.   NaN  Orthodox           NaN
# ...                   ...     ...       ...   ...       ...           ...
# 3591        Zhang Tiequan   5' 8"  155 lbs.   69"  Orthodox  Jul 25, 1978
# 3592          Alex Zuniga     NaN  145 lbs.   NaN       NaN           NaN
# 3593        George Zuniga   5' 9"  185 lbs.   NaN       NaN           NaN
# 3594         Allan Zuniga   5' 7"  155 lbs.   70"  Orthodox  Apr 04, 1992
# 3595       Virgil Zwicker   6' 2"  205 lbs.   74"       NaN  Jun 26, 1982
#
#       SLpM Str_Acc  SApM Str_Def  TD_Avg TD_Acc TD_Def  Sub_Avg
# ...

# %%
volk= fighter_stats[fighter_stats['fighter_name']== 'Alexander Volkanovski']

volk
# Out:
#                fighter_name Height    Weight Reach    Stance           DOB  \
# 3394  Alexander Volkanovski  5' 6"  145 lbs.   71"  Orthodox  Sep 29, 1988
#
#       SLpM Str_Acc  SApM Str_Def  TD_Avg TD_Acc TD_Def  Sub_Avg
# 3394  6.02     55%  3.31     60%    2.09    34%    72%      0.3

# %%
max_= fighter_stats[fighter_stats['fighter_name']== 'Max Holloway']


max_
# Out:
#       fighter_name  Height    Weight Reach    Stance           DOB  SLpM  \
# 1376  Max Holloway  5' 11"  145 lbs.   69"  Orthodox  Dec 04, 1991  7.26
#
#      Str_Acc  SApM Str_Def  TD_Avg TD_Acc TD_Def  Sub_Avg
# 1376     46%  4.58     60%    0.21    71%    84%      0.3

# %%
fighter_stats= pd.concat([volk, max_ ], axis=0)
fighter_stats.T
# Out:
#                                3394          1376
# fighter_name  Alexander Volkanovski  Max Holloway
# Height                        5' 6"        5' 11"
# Weight                     145 lbs.      145 lbs.
# Reach                           71"           69"
# Stance                     Orthodox      Orthodox
# DOB                    Sep 29, 1988  Dec 04, 1991
# SLpM                           6.02          7.26
# Str_Acc                         55%           46%
# SApM                           3.31          4.58
# Str_Def                         60%           60%
# TD_Avg                         2.09          0.21
# TD_Acc                          34%           71%
# TD_Def                          72%           84%
# Sub_Avg                         0.3           0.3

# %%
###################################################################################################################################

# %%
csv2=r"C:\Users\VANT\ironhack\ejercicios\w5-data-visuals\data\ufc_event_data.csv"

fight_stats=pd.read_csv(csv2)

# %%
fight_stats
# Out:
#                                Event Name      Event Date          Result  \
# 0     UFC Fight Night: Vera vs. Sandhagen  March 25, 2023  Cory Sandhagen
# 1     UFC Fight Night: Vera vs. Sandhagen  March 25, 2023      Holly Holm
# 2     UFC Fight Night: Vera vs. Sandhagen  March 25, 2023   Nate Landwehr
# 3     UFC Fight Night: Vera vs. Sandhagen  March 25, 2023   Maycee Barber
# 4     UFC Fight Night: Vera vs. Sandhagen  March 25, 2023   Albert Duraev
# ...                                   ...             ...             ...
# 7055                    UFC 2: No Way Out  March 11, 1994    Orlando Wiet
# 7056                    UFC 2: No Way Out  March 11, 1994   Frank Hamaker
# 7057                    UFC 2: No Way Out  March 11, 1994   Johnny Rhodes
# 7058                    UFC 2: No Way Out  March 11, 1994   Patrick Smith
# 7059                    UFC 2: No Way Out  March 11, 1994    Scott Morris
#
#             Fighter1          Fighter2   KD Strikes   TD  Sub  \
# ...

# %%
Trilogy= fight_stats[(fight_stats['Fighter2'] == 'Max Holloway')][0:3]
Trilogy
# Out:
#                            Event Name         Event Date  \
# 367   UFC 276: Adesanya vs. Cannonier      July 02, 2022
# 1405      UFC 251: Usman vs. Masvidal      July 11, 2020
# 1613     UFC 245: Usman vs. Covington  December 14, 2019
#
#                      Result               Fighter1      Fighter2   KD  \
# 367   Alexander Volkanovski  Alexander Volkanovski  Max Holloway  0-0
# 1405  Alexander Volkanovski  Alexander Volkanovski  Max Holloway  0-0
# 1613  Alexander Volkanovski  Alexander Volkanovski  Max Holloway  0-0
#
#       Strikes   TD  Sub   Weight Class Method  Round  Time
# 367   199-127  0-0  0-0  Featherweight  U-DEC      5  5:00
# 1405  137-102  3-0  0-0  Featherweight  S-DEC      5  5:00
# 1613  157-134  0-0  0-0  Featherweight  U-DEC      5  5:00

# %%
Trilogy['Event Name'] = Trilogy['Event Name'].str.split(':').str[0]

# %%
Trilogy.T
# Out:
#                                367                    1405  \
# Event Name                  UFC 276                UFC 251
# Event Date            July 02, 2022          July 11, 2020
# Result        Alexander Volkanovski  Alexander Volkanovski
# Fighter1      Alexander Volkanovski  Alexander Volkanovski
# Fighter2               Max Holloway           Max Holloway
# KD                              0-0                    0-0
# Strikes                     199-127                137-102
# TD                              0-0                    3-0
# Sub                             0-0                    0-0
# Weight Class          Featherweight          Featherweight
# Method                        U-DEC                  S-DEC
# Round                             5                      5
# Time                           5:00                   5:00
#
#                                1613
# Event Name                  UFC 245
# Event Date        December 14, 2019
# ...

# %%
csv3=r"C:\Users\VANT\iron\proyectos\web_scrapin_w4_1\src\api_limpio5.csv"
pd.reset_option('display.max_columns', None)
fighters=pd.read_csv(csv3)

# %%
fighters
# Out:
#                     Name   Nickname          Division_Title  _Strikes_Landed  \
# 0           Max Holloway    Blessed  Featherweight Division             3122
# 1  Alexander Volkanovski  The Great  Featherweight Division             1442
#
#    _Strikes_Attempted  Takedowns_Landed  Takedowns_Attempted  \
# 0                6586                 4                   15
# 1                2549                16                   67
#
#   Striking_accuracy Takedown_Accuracy  \
# 0               47%               53%
# 1               57%               34%
#
#                                        Fighter_Facts  ...  Sig_Str_Absorbed  \
# 0  ['Pro since 2010', 'Ten wins by KO, two by sub...  ...              4.79
# 1                                                NaN  ...              3.40
#
#    Takedown_avg  Submission_avg Sig_Str_Defense Takedown_Defense  \
# 0          0.28            0.31             60%              84%
# ...

# %%
column_to_delete = 'Fighter_Facts'
fighters.drop(column_to_delete, axis=1, inplace=True)

# %%
fighters.T
# Out:
#                                               0                        1
# Name                               Max Holloway    Alexander Volkanovski
# Nickname                                Blessed                The Great
# Division_Title           Featherweight Division   Featherweight Division
# _Strikes_Landed                            3122                     1442
# _Strikes_Attempted                         6586                     2549
# Takedowns_Landed                              4                       16
# Takedowns_Attempted                          15                       67
# Striking_accuracy                           47%                      57%
# Takedown_Accuracy                           53%                      34%
# Wins                                         24                       25
# Losses                                        7                        2
# Draws                                         0                        0
# ...

# %%
fighters.fillna(0, inplace=True)

# %%
fighters
# Out:
#                     Name   Nickname          Division_Title  _Strikes_Landed  \
# 0           Max Holloway    Blessed  Featherweight Division             3122
# 1  Alexander Volkanovski  The Great  Featherweight Division             1442
#
#    _Strikes_Attempted  Takedowns_Landed  Takedowns_Attempted  \
# 0                6586                 4                   15
# 1                2549                16                   67
#
#   Striking_accuracy Takedown_Accuracy  Wins  ...  Sig_Str_Absorbed  \
# 0               47%               53%    24  ...              4.79
# 1               57%               34%    25  ...              3.40
#
#    Takedown_avg Submission_avg Sig_Str_Defense Takedown_Defense Knockdown_Avg  \
# 0          0.28           0.31             60%              84%          0.28
# 1          1.52           0.20             59%              69%          0.40
#
#    Average_fight_time  First_Round_Finishes           Date Fighter_id
# ...

# %%
nueva_columna = ['Alex Volkanovski','Max Holloway']  # Valores para la nueva columna
fighter_stats['name'] = nueva_columna

# %%
nueva_columna = ['https://dmxg5wxfqgb4u.cloudfront.net/styles/athlete_bio_full_body/s3/2023-07/VOLKANOVSKI_ALEXANDER_L_BELT_07-08.png?itok=FewlqaNo','https://dmxg5wxfqgb4u.cloudfront.net/styles/athlete_bio_full_body/s3/2023-04/HOLLOWAY_MAX_L_04-15.png?itok=TQ_xcSO-']  # Valores para la nueva columna
fighter_stats['url'] = nueva_columna

# %%
fighter_stats
# Out:
#                fighter_name  Height    Weight Reach    Stance           DOB  \
# 3394  Alexander Volkanovski   5' 6"  145 lbs.   71"  Orthodox  Sep 29, 1988
# 1376           Max Holloway  5' 11"  145 lbs.   69"  Orthodox  Dec 04, 1991
#
#       SLpM Str_Acc  SApM Str_Def  TD_Avg TD_Acc TD_Def  Sub_Avg  \
# 3394  6.02     55%  3.31     60%    2.09    34%    72%      0.3
# 1376  7.26     46%  4.58     60%    0.21    71%    84%      0.3
#
#                   name                                                url
# 3394  Alex Volkanovski  https://dmxg5wxfqgb4u.cloudfront.net/styles/at...
# 1376      Max Holloway  https://dmxg5wxfqgb4u.cloudfront.net/styles/at...

# %%
Trilogy
# Out:
#      Event Name         Event Date                 Result  \
# 367     UFC 276      July 02, 2022  Alexander Volkanovski
# 1405    UFC 251      July 11, 2020  Alexander Volkanovski
# 1613    UFC 245  December 14, 2019  Alexander Volkanovski
#
#                    Fighter1      Fighter2   KD  Strikes   TD  Sub  \
# 367   Alexander Volkanovski  Max Holloway  0-0  199-127  0-0  0-0
# 1405  Alexander Volkanovski  Max Holloway  0-0  137-102  3-0  0-0
# 1613  Alexander Volkanovski  Max Holloway  0-0  157-134  0-0  0-0
#
#        Weight Class Method  Round  Time
# 367   Featherweight  U-DEC      5  5:00
# 1405  Featherweight  S-DEC      5  5:00
# 1613  Featherweight  U-DEC      5  5:00

# %%
output_file_path = 'fighters.csv'
fighters.to_csv(output_file_path, index=False)

# %%
output_file_path = 'fighters_stats3.csv'
fighter_stats.to_csv(output_file_path, index=False)

# %%
output_file_path = 'Trilogy.csv'
Trilogy.to_csv(output_file_path, index=False)
